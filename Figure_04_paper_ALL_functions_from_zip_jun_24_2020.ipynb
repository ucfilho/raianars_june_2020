# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/raianars_june_2020/blob/master/Figure_04_paper_ALL_functions_from_zip_jun_24_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import zipfile
from matplotlib import pyplot as PLT
plt.style.use('seaborn-whitegrid')
from pylab import *

# TRAIN DATASET
# !git clone https://github.com/RaianaSeixas/ANN #clonar do Github
# %cd ANN
#!ls
print("Hello world"+"\n"+"I'm evolving!!!"+"\n")

# %matplotlib inline
# Out:
# fatal: destination path 'ANN' already exists and is not an empty directory.
# /content/ANN
# Hello world
# I'm evolving!!!

# %%
Transfere='imput_ANN_D10_30_out_07_19.zip'
file_name = zipfile.ZipFile(Transfere, 'r')
file_name.extractall()

# %%
labels=[]
with zipfile.ZipFile(Transfere, "r") as f:
  for f in f.namelist():
    labels.append(f)

# %%
# 2019-10-07_12h50min_DE_Rosenbrock_30.xlsx

# %%
i=0
for name in labels:
  print('i=',i,name)
  i=i+1
# Out:
# i= 0 2019-10-05_02h51min_DE_Rosenbrock_10.csv
# i= 1 2019-10-05_02h58min_DE_Sphere_10.csv
# i= 2 2019-10-05_03h13min_DE_Rastrigin_10.csv
# i= 3 2019-10-05_03h20min_DE_Schwefel_10.csv
# i= 4 2019-10-05_03h27min_DE_Sum_of_different_powers_10.csv
# i= 5 2019-10-05_03h36min_DE_Ackley_10.csv
# i= 6 2019-10-05_03h42min_DE_Michalewicz_10.csv
# i= 7 2019-10-07_12h50min_DE_Rosenbrock_30.csv
# i= 8 2019-10-07_13h05min_DE_Sphere_30.csv
# i= 9 2019-10-07_13h40min_DE_Schwefel_30.csv
# i= 10 2019-10-07_14h17min_DE_Rastrigin_30.csv
# i= 11 2019-10-07_14h35min_DE_Sum_of_different_powers_30.csv
# i= 12 2019-10-07_14h53min_DE_Ackley_30.csv
# i= 13 2019-10-07_15h14min_DE_Michalewicz_30.csv

# %%
file_selected=labels[11] # just to test...
print(file_selected)
# Out:
# 2019-10-07_14h35min_DE_Sum_of_different_powers_30.csv

# %%
df=pd.read_csv(file_selected)

# %%
#print(df)

# %%
col_names=df.columns
print(col_names)
# Out:
# Index(['Unnamed: 0', 'DIVERSIDADE (DI)', 'DI RELATIVO', 'FRAC Its',
#        'VELOC FOBJ', 'VELOC X', 'NP', 'Fo', 'CRo', 'fmin', 'fmax', 'AD_fmin',
#        'AD_fmax', 'DELTA FOBJ', 'DELTA VX', 'r_fitness', 'F', 'CR',
#        'FUNCTION'],
#       dtype='object')

# %%
fields=['DI RELATIVO', 'FRAC Its','Fo', 'CRo', 'F', 'CR']

# %%
Y_CR=np.array(df['F'])
Y_F=np.array(df['CR'])
Num=len(Y_F)
X_F=np.zeros(Num)
for i in range(Num):
  X_F[i]=(i)/Num

# %%
fig = PLT.figure()
ax1 = fig.add_subplot(111)
ax1.set_xlim(0, 1)
ax1.set_ylim(0, 1)
plt.setp(ax1.spines.values(), linewidth=2.0)
plt.plot(X_F, Y_F, 'ko--', X_F, Y_CR, 'k^-', linewidth=2, markersize=12)
ax1.grid(False)
# Change size and font of tick labels
# Again, this doesn't work in interactive mode.
fontsize = 14
ax = gca()

for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontsize(fontsize)
    tick.label1.set_fontweight('bold')
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontsize(fontsize)
    tick.label1.set_fontweight('bold')

xlabel('Fraction intearations', fontsize=16, fontweight='bold')
ylabel('F and CR', fontsize=16, fontweight='bold')
#ax.legend( ('F', 'CR'), loc='upper right')
ax.legend( ('F', 'CR'), loc=[0.8,0.5])

# %%
fields=[2,0, 4,10,7,11,9,12,13] 
# Rastrigin 10, Rosembrook 10, sum power 10, Rastringin 30, Rosembrock 30, sum power 30, Schwefel 30, Ackley 30, Michalewicz 30
places_x=[0.8,0.8,0.8,0.8,0.8,0.8,0.8,0.9,0.8]
places_y=[0.5,0.4,0.6,0.6,0.4,0.6,0.45,0.4,0.2]
places_y=[0.9,0.9,0.9,0.9,0.9,0.9,0.9,0.9,0.9]

# %%
Rows_Var=['SeiCo D=10', 'SeiCo D=30',
          'Sphere D=10','Sphere D=30',
          'Rastrigin D=10','Rastrigin D=30',
          'Schwefel D=10','Schwefel D=30',
          'Sum diff. powers D=10','Sum diff. powers D=30',
          'Ackley D=10','Ackley D=30',
          'Michalewicz D=10', 'Michalewicz D=30']
Seq=[0,7,   1,8,   2,10,  3,9,   4,11,   5,12,  6, 13]

Legends=['a)', 'b)','c)','d)','e)','f)','g)','h)','i)','j)','k)','l)','m)', 'n)']

Cols_name=['a-SeiCo D=10',' ','b-SeiCo D=30',' ',
          'c-Sphere D=10',' ','d-Sphere D=30',' ',
          'e-Rastrigin D=10',' ','f -Rastrigin D=30',' ',
          'g-Schwefel 2.26 D=10',' ','h-Schwefel 2.26 D=30',' ',
          'i -Sum diff. powers D=10',' ','j -Sum diff. powers D=30',' ',
          'k-Ackley D=10',' ','l -Ackley D=30',' ',
          'm-Michalewicz D=10',' ', 'n -Michalewicz D=30']

# %%
Num=14

for i in range(Num):
  plt.subplot(5,3,i+1)
  file_selected=labels[Seq[i]]
  df=pd.read_csv(file_selected)
  Y_CR=np.array(df['F'])
  Y_F=np.array(df['CR'])
  plt.xlim(0, 1.0)
  plt.ylim(0, 1.5)
  plt.setp(ax1.spines.values(), linewidth=2.0)
  plt.plot(X_F, Y_F, 'ko--', X_F, Y_CR, 'k^-', linewidth=2, markersize=6)
  plt.legend( ('F', 'CR'), loc=[0.7,0.8], fontsize=10)
  plt.text(-0.2,1.6,Legends[i],fontsize=16)
  plt.xlabel('Fraction intearations', fontsize=11, fontweight='bold')
  plt.ylabel('F and CR', fontsize=11, fontweight='bold')
  plt.grid(True, linewidth=1,color='gray')
  plt.tick_params(axis='both', which='major', labelsize=15)
  
h=90
dh=10
hh=80 
yr = []; k = 0
plt.subplot(5,3,Num+1)
plt.plot()
plt.ylim(0, hh)     # set the ylim to bottom, top
plt.xlim(0, hh)     # set the ylim to bottom, top
plt.axis('off')
plt.text(-10,hh-25,'Legend:',fontsize=14, color = 'k')
for i in range(27):
  if i < 14:
    xpos = -10
    y=h-i*4-5*dh
    yr.append(y)
  else:
    xpos = 40
    y=yr[k]
    k = k +1
  dy =y -8
  plt.text(xpos,y,Cols_name[i],fontsize=12, color = 'k')
  #plt.text(xpos,y,' ',fontsize=12, color = 'k')
  #plt.text(xpos,dy,'---',fontsize=30, color = 'k')
#plt.subplots_adjust(bottom=0.1, right=4, top=4,hspace=0.4, wspace=0.4)
plt.subplots_adjust(bottom=0.2, right=2, top=3,hspace=0.4, wspace=0.4)
